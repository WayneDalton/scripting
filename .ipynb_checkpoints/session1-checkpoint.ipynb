# %% [markdown]
# # Session 1: Introduction to Cyber Scripting
# Welcome to your first hands-on session. Today, we are learning how to manipulate data using Python.
#
# ### Core Concept: Variables
# Think of a variable as a labeled evidence container. We drop data into it so we can use or analyze it later.

# %%
# Click this cell and press Shift + Enter to run it
malicious_ip = "192.168.1.105"
print("ALERT: Unauthorized access attempt detected from:")
print(malicious_ip)
# Out:
# ALERT: Unauthorized access attempt detected from:
# 192.168.1.105

# %% [markdown]
# ### 🛠️ Micro-Challenge 1: Create Your Own Label
# In the empty cell below, do the following:
# 1. Create a variable named `target_user` and assign it a name (e.g., "admin").
# 2. Create a second variable named `failed_attempts` and assign it a number.
# 3. Print a message combining them (e.g., "User admin has 5 failed login attempts").

# %%
# Your code goes here!
